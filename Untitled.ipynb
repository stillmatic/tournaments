# %%
import tournament2
import pandas as pd
import seaborn as sns
from pandas_ply import install_ply, X, sym_call
install_ply(pd)
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# params = {'alpha': 3500, 'beta': 35, 'seed': 30, 'dist': 'exp'}
sim = tournament2.Simulation(48, 6, 100, dist = 'lognorm')
sim.simulate()
sns.distplot(sim.get_results()['wins']/100)
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim2 = tournament2.Simulation(48, 6, 100, **{'dist': 'unif'})
sim2.plot_distribution()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim3 = tournament2.Simulation(48, 6, 100, **{'dist': 'exp', 'seed': 30})
sim3.plot_distribution()
sim3.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# sim3.get_results()
sim3._get_aggregate()
# sim3.plot_strengths()
# Out:
#           strength avg_break  avg_wins
# strength
# 0.026985  0.026985      True      7.21
# 0.031626  0.031626      True     10.16
# 0.093985  0.093985      True     51.83
# 0.146454  0.146454      True     72.26
# 0.178709  0.178709      True     47.13
# 0.217872  0.217872      True     72.72
# 0.238360  0.238360      True    122.10
# 0.267955  0.267955      True    150.51
# 0.268115  0.268115      True     97.73
# 0.273104  0.273104      True     88.20
# 0.280815  0.280815      True    109.49
# 0.311010  0.311010      True     32.71
# 0.337482  0.337482      True     70.57
# 0.379992  0.379992      True     99.45
# 0.408332  0.408332      True     96.39
# 0.425031  0.425031      True    204.37
# 0.425660  0.425660      True    122.08
# 0.457265  0.457265      True    192.08
# 0.468236  0.468236      True    160.00
# 0.472279  0.472279      True     82.69
# 0.479244  0.479244      True    100.89
# 0.488008  0.488008      True    226.17
# 0.522038  0.522038      True    186.92
# ...
