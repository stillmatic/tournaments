# %%
import tournament2
import pandas as pd
import seaborn as sns
from pandas_ply import install_ply, X, sym_call
install_ply(pd)
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# params = {'alpha': 3500, 'beta': 35, 'seed': 30, 'dist': 'exp'}
sim = tournament2.Simulation(48, 6, 100, dist = 'lognorm')
sim.simulate()
sim.plot_distribution()
sim.plot_strengths()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-4bc8cc3e36f9> in <module>()
#       1 # params = {'alpha': 3500, 'beta': 35, 'seed': 30, 'dist': 'exp'}
# ----> 2 sim = tournament2.Simulation(48, 6, 100, dist = 'lognorm')
#       3 sim.simulate()
#       4 sim.plot_distribution()
#       5 sim.plot_strengths()
#
# /Users/christopherhua/code/tournament/tournament2.py in __init__(self, n_teams, n_rounds, n_sim, **kwargs)
#     201         self.n_rounds = n_rounds
#     202         self.dist = kwargs.get('dist', 'lognormal')
# --> 203         self.tourney = Tournament(n_teams, n_rounds, **kwargs)
#     204         self.df = pd.DataFrame()
#     205
#
# /Users/christopherhua/code/tournament/tournament2.py in __init__(self, n_teams, n_rounds, **kwargs)
#      29         self.dist = kwargs.get('dist', 'lognormal')
#      30         self.dist_params = kwargs.get('dist_params', None)
# ---> 31         self.strengths = self._generate_teams()
#      32         self.wins = [0] * self.n_teams
#      33         self.alpha = kwargs.get('alpha', 3500)
#
# /Users/christopherhua/code/tournament/tournament2.py in _generate_teams(self)
#      72             strengths = np.random.uniform(l, h, size=self.n_teams)
#      73         elif(self.dist == "lognorm"):
# ---> 74             mu = self.dist_params['mean'] or 0.0
#      75             sigma = self.dist_params['sigma'] or 1.0
#      76             strengths = np.random.lognormal(mu, sigma, size=self.n_teams)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
sim2 = tournament2.Simulation(48, 6, 100, **{'dist': 'unif'})
sim2.plot_distribution()
sim2.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim3 = tournament2.Simulation(48, 6, 2, **{'dist': 'exp', 'seed': 30, 'dist_params': {'scale': 1.5}})
sim3.plot_distribution()
sim3.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim3.get_results()
# sim3.plot_distribution()
# Out:
#     strength  wins
# 0   1.549842     4
# 1   0.718866     3
# 2   1.631722     2
# 3   0.268063     2
# 4   4.929440     6
# 5   0.638491     2
# 6   7.196494     4
# 7   0.401933     3
# 8   1.321727     2
# 9   0.783058     3
# 10  0.219681     1
# 11  1.178342     4
# 12  1.095266     4
# 13  2.184143     2
# 14  4.073749     5
# 15  0.140977     2
# 16  0.326807     3
# 17  7.723214     5
# 18  0.402173     2
# 19  0.409656     2
# 20  1.487734     3
# 21  1.991770     4
# 22  1.748785     2
# 23  0.047438     0
# 24  3.492067     5
# 25  0.506223     3
# 26  1.216588     3
# 27  0.708418     3
# 28  0.040478     1
# 29  1.022270     3
# ..       ...   ...
# 18  0.402173     5
# 19  0.409656     5
# 20  1.487734     7
# 21  1.991770     9
# 22  1.748785     6
# 23  0.047438     2
# 24  3.492067     8
# 25  0.506223     5
# 26  1.216588     7
# 27  0.708418     7
# 28  0.040478     2
# 29  1.022270     6
# 30  2.700127     7
# 31  0.685897     6
# 32  1.086592     6
# 33  0.959066     4
# 34  0.732012     6
# 35  2.044670     8
# 36  0.612499     6
# 37  1.357426     7
# 38  0.569989     5
# 39  0.637546     5
# 40  0.421222     4
# 41  1.795745     6
# 42  0.357540     4
# 43  0.466514     5
# 44  0.702354     8
# 45  1.276768     6
# 46  3.739857     8
# 47  2.563688     9
#
# [96 rows x 2 columns]
