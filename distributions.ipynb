# %%
import tournament2
import pandas as pd
import seaborn as sns
import numpy as np
from pandas_ply import install_ply, X, sym_call
install_ply(pd)
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# params = {'alpha': 3500, 'beta': 35, 'seed': 30, 'dist': 'exp'}
sim = tournament2.Simulation(48, 6, 100, dist = 'lognorm')
sim.simulate()
sim.plot_distribution()
sim.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim2 = tournament2.Simulation(48, 6, 100, **{'dist': 'unif', 'params': {'low': 0, 'high': 2}})
sim2.plot_distribution()
sim2.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim3 = tournament2.Simulation(48, 6, 20, **{'dist': 'exp', 'seed': 30, 'dist_params': {'scale': 1.5}})
sim3.plot_distribution()
sim3.plot_strengths()
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sim3.plot_distribution(bins = 7)
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Out:
# /Users/christopherhua/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
